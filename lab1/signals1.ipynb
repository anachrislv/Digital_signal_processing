# %%
import os
import numpy as np
import scipy as sp
import librosa
import matplotlib.pyplot as plt
import IPython
import sounddevice as sd
import soundfile as sf
# %matplotlib inline

# %%
#MEROS 1
L=256
w1=np.pi/9
w2=np.pi/5

N=256 #deigmata
#f=2 * numpy.pi /5
T = 256
x = np.arange(0.0, T, 1)
w=0.54-0.46*np.cos(2 * np.pi * x /L)
y=w*(np.exp((1j*(w1*x))) +0.9*np.exp((1j*(w2*x))))

yf=sp.fftpack.fft(y)
yf=np.sqrt(yf.real**2 +yf.imag**2)
plt.plot( yf)
plt.show()
#plt.plot(x, y)
plt.show()

print("w2prin=",w2)

print("w2prin=",w2)
for i in range(20):
    w2=w2-0.02
    y=w*(np.exp((1j*(w1*x))) +0.9*np.exp((1j*(w2*x))))
    yf=sp.fftpack.fft(y)
    yf=np.sqrt(yf.real**2 +yf.imag**2)
    print("i=", i)
    print((i+1)*0.02)
    print("w2=",w2)
    if (i==10):
        print("gia i=10 Dw=", abs(w1-w2))
    elif (i==11):
        print("gia i=11 Dw=", abs(w1-w2))
        print("molis pou diakrinontai")
    plt.plot( yf) #ginetai gia i=12 opou to w2 exei meiwthei kata 1.3
    plt.show()
# Out:
# w2prin= 0.6283185307179586
# w2prin= 0.6283185307179586
# i= 0
# 0.02
# w2= 0.6083185307179586
# i= 1
# 0.04
# w2= 0.5883185307179586
# i= 2
# 0.06
# w2= 0.5683185307179586
# i= 3
# 0.08
# w2= 0.5483185307179586
# i= 4
# 0.1
# w2= 0.5283185307179585
# i= 5
# 0.12
# w2= 0.5083185307179585
# i= 6
# 0.14
# w2= 0.4883185307179585
# i= 7
# 0.16
# w2= 0.4683185307179585
# i= 8
# 0.18
# w2= 0.44831853071795846
# i= 9
# 0.2
# w2= 0.42831853071795845
# i= 10
# 0.22
# w2= 0.40831853071795843
# gia i=10 Dw= 0.05925268031909253
# i= 11
# 0.24
# w2= 0.3883185307179584
# gia i=11 Dw= 0.039252680319092514
# molis pou diakrinontai
# i= 12
# 0.26
# w2= 0.3683185307179584
# i= 13
# 0.28
# w2= 0.3483185307179584
# i= 14
# 0.3
# w2= 0.32831853071795836
# i= 15
# 0.32
# w2= 0.30831853071795834
# i= 16
# 0.34
# w2= 0.2883185307179583
# i= 17
# 0.36
# w2= 0.2683185307179583
# i= 18
# 0.38
# w2= 0.2483185307179583
# i= 19
# 0.4
# w2= 0.22831853071795832

# %%
L=256
N=512
x = np.arange(0.0, L, 1)
z=np.arange(0, N, 1)
w2=np.pi/5
w1=np.pi/9

for i in range(20):
    w2=w2-0.02
    y=np.hamming(L)*(np.exp((1j*(w1*x))) +0.9*np.exp((1j*(w2*x))))
    yf=np.fft.fft(y, N)
    yf=np.sqrt(yf.real**2 + yf.imag**2)
    print("i=", i)
    print((i+1)*0.02)
    print("w2=",w2)
    if (i==10):
        print("gia i=10 Dw=", abs(w1-w2))
    elif (i==11):
        print("gia i=11 Dw=", abs(w1-w2))
        print("molis pou diakrinontai")

    plt.plot( z,  yf)
    plt.show()

    plt.show()
# Out:
# i= 0
# 0.02
# w2= 0.6083185307179586
# i= 1
# 0.04
# w2= 0.5883185307179586
# i= 2
# 0.06
# w2= 0.5683185307179586
# i= 3
# 0.08
# w2= 0.5483185307179586
# i= 4
# 0.1
# w2= 0.5283185307179585
# i= 5
# 0.12
# w2= 0.5083185307179585
# i= 6
# 0.14
# w2= 0.4883185307179585
# i= 7
# 0.16
# w2= 0.4683185307179585
# i= 8
# 0.18
# w2= 0.44831853071795846
# i= 9
# 0.2
# w2= 0.42831853071795845
# i= 10
# 0.22
# w2= 0.40831853071795843
# gia i=10 Dw= 0.05925268031909253
# i= 11
# 0.24
# w2= 0.3883185307179584
# gia i=11 Dw= 0.039252680319092514
# molis pou diakrinontai
# i= 12
# 0.26
# w2= 0.3683185307179584
# i= 13
# 0.28
# w2= 0.3483185307179584
# i= 14
# 0.3
# w2= 0.32831853071795836
# i= 15
# 0.32
# w2= 0.30831853071795834
# i= 16
# 0.34
# w2= 0.2883185307179583
# i= 17
# 0.36
# w2= 0.2683185307179583
# i= 18
# 0.38
# w2= 0.2483185307179583
# i= 19
# 0.4
# w2= 0.22831853071795832

# %%
L=256
N=1024
x = np.arange(0.0, L, 1)
z=np.arange(0, N, 1)
w2=np.pi/5
w1=np.pi/9

for i in range(20):
    w2=w2-0.02
    y=np.hamming(L)*(np.exp((1j*(w1*x))) +0.9*np.exp((1j*(w2*x))))
    yf=np.fft.fft(y, N)
    yf=np.sqrt(yf.real**2 + yf.imag**2)
    print("i=", i)
    print((i+1)*0.02)
    print("w2=",w2)
    if (i==10):
        print("gia i=10 Dw=", abs(w1-w2))
    elif (i==11):
        print("gia i=11 Dw=", abs(w1-w2))
        print("molis pou diakrinontai")

   
    plt.plot( z,  yf)
    plt.show()

    plt.show()
# Out:
# i= 0
# 0.02
# w2= 0.6083185307179586
# i= 1
# 0.04
# w2= 0.5883185307179586
# i= 2
# 0.06
# w2= 0.5683185307179586
# i= 3
# 0.08
# w2= 0.5483185307179586
# i= 4
# 0.1
# w2= 0.5283185307179585
# i= 5
# 0.12
# w2= 0.5083185307179585
# i= 6
# 0.14
# w2= 0.4883185307179585
# i= 7
# 0.16
# w2= 0.4683185307179585
# i= 8
# 0.18
# w2= 0.44831853071795846
# i= 9
# 0.2
# w2= 0.42831853071795845
# i= 10
# 0.22
# w2= 0.40831853071795843
# gia i=10 Dw= 0.05925268031909253
# i= 11
# 0.24
# w2= 0.3883185307179584
# gia i=11 Dw= 0.039252680319092514
# molis pou diakrinontai
# i= 12
# 0.26
# w2= 0.3683185307179584
# i= 13
# 0.28
# w2= 0.3483185307179584
# i= 14
# 0.3
# w2= 0.32831853071795836
# i= 15
# 0.32
# w2= 0.30831853071795834
# i= 16
# 0.34
# w2= 0.2883185307179583
# i= 17
# 0.36
# w2= 0.2683185307179583
# i= 18
# 0.38
# w2= 0.2483185307179583
# i= 19
# 0.4
# w2= 0.22831853071795832

# %%
w2 = np.pi/5
w1 = np.pi/9
print(w2)
L = 512
N = 1024
x = np.arange(0,L,1)
f = np.arange(0,N,1)
for i in range(15):
    w2=w2-0.02
    y=np.hamming(L)*(np.exp((1j*(w1*x))) +0.9*np.exp((1j*(w2*x))))
    yf=np.fft.fft(y,N)
    yf=np.sqrt(yf.real**2 +yf.imag**2)
    print("i=", i)
    print((i+1)*0.02)
    print("w2=",w2)
    if (i==11):
        print("gia i=11 Dw=", abs(w1-w2))
        print("molis pou diakrinontai")
    elif (i==12):
        print("gia i=12 Dw=", abs(w1-w2))
    plt.plot(f,yf) #ginetai gia i=12 opou to w2 exei meiwthei kata 1.3
    plt.show()
# Out:
# 0.6283185307179586
# i= 0
# 0.02
# w2= 0.6083185307179586
# i= 1
# 0.04
# w2= 0.5883185307179586
# i= 2
# 0.06
# w2= 0.5683185307179586
# i= 3
# 0.08
# w2= 0.5483185307179586
# i= 4
# 0.1
# w2= 0.5283185307179585
# i= 5
# 0.12
# w2= 0.5083185307179585
# i= 6
# 0.14
# w2= 0.4883185307179585
# i= 7
# 0.16
# w2= 0.4683185307179585
# i= 8
# 0.18
# w2= 0.44831853071795846
# i= 9
# 0.2
# w2= 0.42831853071795845
# i= 10
# 0.22
# w2= 0.40831853071795843
# i= 11
# 0.24
# w2= 0.3883185307179584
# gia i=11 Dw= 0.039252680319092514
# molis pou diakrinontai
# i= 12
# 0.26
# w2= 0.3683185307179584
# gia i=12 Dw= 0.019252680319092497
# i= 13
# 0.28
# w2= 0.3483185307179584
# i= 14
# 0.3
# w2= 0.32831853071795836

# %%
A1 = 1
A2 = 0.05

L = 256
N = 1024
n = np.arange(0,L, 1)

j = complex(0,1)


w1 = 0.35*np.pi 
w2 = 0.4*np.pi 

x1 = A1*np.exp(j*w1*n)
x2 = A2*np.exp(j*w2*n)

y = np.hamming(L)*(x1 + x2)

Y = np.fft.fft(y,N)
Y = np.abs(Y)
f = np.arange(0,N,1)

plt.title('DFT with L = 256 and N = 1024')
plt.xlabel('Frequency f')
plt.ylabel('Amplitude')
plt.plot(f,Y)
plt.show()

# %%
A1 = 1
A2 = 0.05

L = 256
N = 1024
n = np.arange(0,L, 1)

j = complex(0,1)


w1 = 0.35*np.pi 
w2 = 0.4*np.pi 

x1 = A1*np.exp(j*w1*n)
x2 = A2*np.exp(j*w2*n)

y = (x1 + x2)

Y = np.fft.fft(y,N)
Y = np.abs(Y)
f = np.arange(0,N,1)

plt.title('DFT with L = 256 and N = 1024')
plt.xlabel('Frequency f')
plt.ylabel('Amplitude')
plt.plot(f,Y)
plt.show()

# %%
#MEROS 2

#2.1
L = 1000 #number of samples
n = np.arange(0,L,1) #split n_axis to 1000 sections

#creating all signals
d0 = np.sin(0.7217*n) + np.sin(1.0247*n)
d1 = np.sin(0.5346*n) + np.sin(0.9273*n)
d2 = np.sin(0.5346*n) + np.sin(1.0247*n)
d3 = np.sin(0.5346*n) + np.sin(1.1328*n)
d4 = np.sin(0.5906*n) + np.sin(0.9273*n)
d5 = np.sin(0.5906*n) + np.sin(1.0247*n)
d6 = np.sin(0.5906*n) + np.sin(1.1328*n)
d7 = np.sin(0.6535*n) + np.sin(0.9273*n)
d8 = np.sin(0.6535*n) + np.sin(1.0247*n)
d9 = np.sin(0.6535*n) + np.sin(1.1328*n)

# %%
#2.2
N = 1000

D5 = np.fft.fft(d5,N)
D5 = np.abs(D5)
k = np.arange(0,N,1)

plt.title('DFT of signal D5 with N = 1000')
plt.xlabel('Frequency f')
plt.ylabel('Amplitude')
plt.plot(k,D5)
plt.show()

# %%
N = 1000

D8 = np.fft.fft(d8,N)
D8 = np.abs(D8)
k = np.arange(0,N,1)

plt.title('DFT of signal D8 with N = 1000')
plt.xlabel('Frequency f')
plt.ylabel('Amplitude')
plt.plot(k,D8)
plt.show()

# %%
#2.3
y = []

for x in d0:
    y.append(x)
for x in range (100):
    y.append(0)
for x in d6:
    y.append(x)
for x in range (100):
    y.append(0)
for x in d2:
    y.append(x)
for x in range (100):
    y.append(0)
for x in d3:
    y.append(x)
for x in range (100):
    y.append(0)
for x in d8:
    y.append(x)
for x in range (100):
    y.append(0)
for x in d2:
    y.append(x)
for x in range (100):
    y.append(0)
for x in d1:
    y.append(x)
for x in range (100):
    y.append(0)
for x in d1:
    y.append(x)


sf.write('tone sequence.wav',y,10000)
    
z = y

# %%
#2.4
#i με τετραγωνικο παραθυρο
Ν  = 1000
y1 = y[:1000]
y2 = y[1100:2100]
y3 = y[2200:3200]
y4 = y[3300:4300]
y5 = y[4400:5400]
y6 = y[5500:6500]
y7 = y[6600:7600]
y8 = y[7700:8700]

Y1 = np.fft.fft(y1,N)
Y1 = np.abs(Y1)
Y2 = np.fft.fft(y2,N)
Y2 = np.abs(Y2)
Y3 = np.fft.fft(y3,N)
Y3 = np.abs(Y3)
Y4 = np.fft.fft(y4,N)
Y4 = np.abs(Y4)
Y5 = np.fft.fft(y5,N)
Y5 = np.abs(Y5)
Y6 = np.fft.fft(y6,N)
Y6 = np.abs(Y6)
Y7 = np.fft.fft(y7,N)
Y7 = np.abs(Y7)
Y8 = np.fft.fft(y8,N)
Y8 = np.abs(Y8)

# %%
#i με hamming παραθυρο
Ν  = 1000
y1 = np.hamming(N)*y[:1000]
y2 = np.hamming(N)*y[1100:2100]
y3 = np.hamming(N)*y[2200:3200]
y4 = np.hamming(N)*y[3300:4300]
y5 = np.hamming(N)*y[4400:5400]
y6 = np.hamming(N)*y[5500:6500]
y7 = np.hamming(N)*y[6600:7600]
y8 = np.hamming(N)*y[7700:8700]

Y1 = np.fft.fft(y1,N)
Y1 = np.abs(Y1)
Y2 = np.fft.fft(y2,N)
Y2 = np.abs(Y2)
Y3 = np.fft.fft(y3,N)
Y3 = np.abs(Y3)
Y4 = np.fft.fft(y4,N)
Y4 = np.abs(Y4)
Y5 = np.fft.fft(y5,N)
Y5 = np.abs(Y5)
Y6 = np.fft.fft(y6,N)
Y6 = np.abs(Y6)
Y7 = np.fft.fft(y7,N)
Y7 = np.abs(Y7)
Y8 = np.fft.fft(y8,N)
Y8 = np.abs(Y8)

# %%
#2.5
#δημιουργουμε λιστα με τους δεικτες k για ολα τα νουμερα(αρα k[0],k[1]->0 ... k[2],k[3]->1 ......)
k = []

D0 = np.fft.fft(d0,N)
D0 = np.abs(D0)
k2 = np.argmax(D0[:500])
k.append(k2)
k1 = np.argmax(D0[(k2+1):500])+k2+1
k.append(k1)


D1 = np.fft.fft(d1,N)
D1 = np.abs(D1)
k2 = np.argmax(D1[:500])
k.append(k2)
k1 = np.argmax(D1[(k2+1):500])+k2+1
k.append(k1)

D2 = np.fft.fft(d2,N)
D2 = np.abs(D2)
k2 = np.argmax(D2[:500])
k.append(k2)
k1 = np.argmax(D2[(k2+1):500])+k2+1
k.append(163)

D3 = np.fft.fft(d3,N)
D3 = np.abs(D3)
k2 = np.argmax(D3[:500])
k.append(k2)
k1 = np.argmax(D3[(k2+1):500])+k2+1
k.append(k1)

D4 = np.fft.fft(d4,N)
D4 = np.abs(D4)
k2 = np.argmax(D4[:500])
k.append(k2)
k1 = np.argmax(D4[(k2+1):500])+k2+1
k.append(k1)

D5= np.fft.fft(d5,N)
D5 = np.abs(D5)
k2 = np.argmax(D5[:500])
k.append(k2)
k1 = np.argmax(D5[(k2+1):500])+k2+1
k.append(k1)

D6= np.fft.fft(d6,N)
D6 = np.abs(D6)
k2 = np.argmax(D6[:500])
k.append(k2)
k1 = np.argmax(D6[(k2+1):500])+k2+1
k.append(k1)


D7= np.fft.fft(d7,N)
D7 = np.abs(D7)
k2 = np.argmax(D7[:500])
k.append(k2)
k1 = np.argmax(D7[(k2+1):500])+k2+1
k.append(k1)

D8 = np.fft.fft(d8,N)
D8 = np.abs(D8)
k2 = np.argmax(D8[:500])
k.append(k2)
k1 = np.argmax(D8[(k2+1):500])+k2+1
k.append(k1)

D9 = np.fft.fft(d9,N)
D9 = np.abs(D9)
k2 = np.argmax(D9[:500])
k.append(k2)
k1 = np.argmax(D9[(k2+1):500])+k2+1
k.append(k1)

print("k = ",k)
# Out:
# k =  [163, 164, 85, 148, 85, 163, 85, 180, 94, 148, 94, 163, 94, 180, 104, 148, 104, 163, 104, 180]

# %%
def search(a,b,xs):
    for i,x in enumerate(xs):
        if xs[i] == a and xs[i+1] == b:
            return i

# %%
def ttdecode(xs):
    y=[]
    d=[]
    y.append(0)
    counter = 0
    for i,x in enumerate(xs):
        if i != 0  and i < (len(xs)-1) and xs[i-1] != 0 and xs[i + 1] == 0 and xs[i] != 0: #ελεγχουμε αν τελειωσε το πατημα του ενος πλήκτρου
            Y = np.fft.fft(y,N) #υπολογισμος του DFT
            Y = np.abs(Y)
            k1 = np.argmax(Y[:500]) #υπολογισμος των συχνοτητων που έχουμε peaks
            k2 = np.argmax(Y[(k1+1):500])+k1+1 
            for i,x in enumerate(k): #ψαχνουμε την αντιστοιχια με την με την λιστα k
                if k[i] == k1  and k[i + 1] == k2:
                    d.append(i//2 )
                
            y = []
        elif i < (len(xs)-1) and xs[i] == 0  and xs[i + 1] == 0: #οσο εχουμε μηδενικα δειγματα προχωραμε στην επομενη επαναληψη
            continue
        else:
            y.append(x)
        if i == len(xs)-1 and xs[i-1] != 0: #corner case 
            Y = np.fft.fft(y,N)
            Y = np.abs(Y)
            k1 = np.argmax(Y[:500])
            k2 = np.argmax(Y[(k1+1):500])+k1+1
            for i,x in enumerate(k):
                if k[i] == k1  and k[i + 1] == k2:
                    d.append(i//2 )
                
    return d;

# %%
print(ttdecode(z))
# Out:
# [0, 6, 2, 3, 8, 2, 1, 1]

# %%
y = np.load('easy_sig.npy')
print(ttdecode(y))
# Out:
# [7, 3, 5, 8, 2, 8, 0, 2]

# %%
y = np.load('hard_sig.npy')
print(ttdecode(y))
# Out:
# [4, 3, 5, 6, 6, 2, 0, 9, 9, 5]

# %%
#MEROS3
# 1

y,fs = librosa.load('speech_utterance.wav',16000)


L = 320 #N = 20ms*fs

y1 = y

y = np.abs(y**2)

En = np.convolve(y,np.hamming(L))
# Out:
# C:\Users\kgk\AppData\Local\Temp/ipykernel_16656/2625216726.py:4: FutureWarning: Pass sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   y,fs = librosa.load('speech_utterance.wav',16000)

# %%
z = []
for i,x in enumerate(y):
    if i == 0 : continue
    z.append(np.sign(y1[i]) - np.sign(y1[i - 1]))

# %%
w = np.ones(320)
z = np.abs(z)
Zn = np.convolve(z,w)

# %%
L  = len(En)
n = np.arange(0,L,1)
plt.title("Short Time Energy")
plt.plot(n,En)
plt.show()

# %%
L  = len(Zn) 
n = np.arange(0,L,1)
plt.title("Zero Crossing-Rate")
plt.plot(n,Zn)
plt.show()

# %%
xs, fs = sf.read('music.wav')

y = []

y = (xs[:,0] + xs [:,1]) / 2

y1 = y

y = np.abs(y**2)

# %%
z = []
for i,x in enumerate(y):
    if i == 0 : continue
    z.append(np.sign(y1[i]) - np.sign(y1[i - 1]))

# %%
w = np.ones(320)
z = np.abs(z)
Zn = np.convolve(z,w)

# %%
L = 960

En = np.convolve(y,np.hamming(L))

L  = len(En)
n = np.arange(0,L,1)
plt.title("Short Time Energy")
plt.plot(n,En)
plt.show()

# %%
L  = len(Zn) 
n = np.arange(0,L,1)
plt.title("Zero Crossing-Rate")
plt.plot(n,Zn)
plt.show()
